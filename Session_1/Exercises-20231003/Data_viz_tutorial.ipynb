# %% [markdown]
# # Graphical statistics

# %% [markdown]
# - Boxplots
# - QQ plots
# - Correlation plots

# %%
import pandas as pd

from matplotlib import pylab as plt
import seaborn as sns  #seaborn is a library producing nicer plots than matplotlib
import scipy as sp

# %% [markdown]
# # $\underline{Boxplots:}$

# %%
#In the same file where you have created your notebook, you need to upload the file 'longAttitude.txt'

# Read the table
df_attitude = pd.read_csv('longAttitude.txt', sep='\t')

# head() returns the first 5 rows of the dataframe
df_attitude.head()
# Out:
#   participant   groups  attitude drink   imagery
# 0          P1  beerpos         1  Beer  Positive
# 1          P2  beerpos        43  Beer  Positive
# 2          P3  beerpos        15  Beer  Positive
# 3          P4  beerpos        40  Beer  Positive
# 4          P5  beerpos         8  Beer  Positive

# %%
# describe() returns some basic statitics of the numerical columns of the dataframe
df_attitude.describe()
# Out:
#          attitude
# count  180.000000
# mean     7.894444
# std     15.374468
# min    -23.000000
# 25%     -5.000000
# 50%      8.000000
# 75%     20.000000
# max     43.000000

# %%
# value_counts() counts the freaquency of each unique item in a columns (best for categorical columns)
df_attitude['drink'].value_counts()
# Out:
# drink
# Beer     60
# Wine     60
# Water    60
# Name: count, dtype: int64

# %% [markdown]
# ---

# %%
sns.set_theme(style="whitegrid")
f, ax = plt.subplots(figsize=(9, 9))
ax = sns.boxplot(x="imagery", y="attitude", data=df_attitude, palette="Set3")
plt.show()

# %%
f, ax = plt.subplots(figsize=(10, 10))
ax = sns.boxplot(x="drink", y="attitude", hue='imagery', data=df_attitude, palette="Set3")
# The parameter hue is useful to get more detailed boxplots. Here we condition on imagery...

# %%
f, ax = plt.subplots(figsize=(10, 10))
ax = sns.boxplot(x="attitude", y="drink", hue="imagery", data=df_attitude, palette="Set2", orient='h')
# Parameter orient returns horizontal boxplots.

# %% [markdown]
# # $\underline{QQ-plots:}$

# %%
# probplot if a function returning a QQ_plot. 
#Parameter dist corresponds to the theoretical quantiles. Here norm is the normal distibution.

f, ax = plt.subplots(figsize=(10, 10))
QQ_plot = sp.stats.probplot(df_attitude['attitude'], dist="expon", plot=plt)

# %% [markdown]
# ## Question:
# Interpret the previous plot and repeat the same experience with Normal and Cauchy distributions. <br>
# Hint: 'norm', 'cauchy'

# %% [markdown]
# # $\underline{Correlation:}$

# %%
#In the same file where you have created your notebook, you need to upload the file 'regression.csv'
df_regression = pd.read_csv('regression.csv', sep=';') #Always check the parameter sep when you upload your file.
df_regression.head()
# Out:
#           V1        V2        V3        V4        V5        V6        V7  \
# 0  18.224967  1.028992  0.622963  0.278925 -0.405870  0.958563 -1.133672
# 1   3.132315  0.604380  1.639447  1.121144 -0.012976 -0.000129  1.603966
# 2 -19.514408 -0.634519  0.093021  0.328398 -1.333980 -0.419870 -0.094647
# 3   5.158179  0.383733 -1.258306  0.955069 -0.094585 -0.337204  2.054539
# 4  21.181815  0.770505 -0.464247  0.066713  1.035105  1.780473  0.563849
#
#          V8        V9       V10       V11
# 0 -0.563239  1.096962  0.420335  0.911695
# 1 -0.074142 -1.036641 -0.451208 -0.225835
# 2 -2.369584  0.859509 -0.310185 -0.101982
# 3 -1.423585  1.220261  0.186976 -0.763621
# 4  0.519628  0.594002 -0.948932  0.258373

# %%
df_regression.describe()
# Out:
#                V1          V2          V3          V4          V5          V6  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     1.866200    0.106671   -0.011075   -0.086213    0.038583   -0.050792
# std     20.074693    0.921415    1.062198    0.950419    1.043892    1.001846
# min    -45.808989   -2.512208   -2.968668   -2.256096   -3.203029   -3.216962
# 25%    -13.051100   -0.466962   -0.689689   -0.774844   -0.638126   -0.734253
# 50%      0.150683    0.120781   -0.069093    0.061547    0.069334   -0.138532
# 75%     18.092876    0.764207    0.619910    0.641472    0.785483    0.695117
# max     52.001064    2.057226    2.456924    1.549438    1.817392    2.447484
#
#                V7          V8          V9         V10         V11
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.015825   -0.043500    0.173027    0.087058   -0.074963
# std      0.947679    1.124056    1.045453    1.144422    0.958011
# min     -2.512321   -2.369584   -2.355831   -2.514274   -1.867200
# 25%     -0.624637   -0.928095   -0.409013   -0.553699   -0.799714
# 50%      0.002869   -0.084932    0.155664    0.032969   -0.000804
# 75%      0.614173    0.737215    0.912155    0.720052    0.589996
# max      2.317906    2.622487    2.557162    3.077316    1.789637

# %%
df_regression.corr()
# Out:
#            V1        V2        V3        V4        V5        V6        V7  \
# V1   1.000000  0.072551 -0.052552 -0.063109  0.167757  0.287429  0.199495
# V2   0.072551  1.000000 -0.153330 -0.019835 -0.048115 -0.046274  0.116381
# V3  -0.052552 -0.153330  1.000000 -0.181632  0.160548  0.055728 -0.012258
# V4  -0.063109 -0.019835 -0.181632  1.000000  0.178020 -0.060489 -0.122038
# V5   0.167757 -0.048115  0.160548  0.178020  1.000000  0.058539 -0.050689
# V6   0.287429 -0.046274  0.055728 -0.060489  0.058539  1.000000 -0.264509
# V7   0.199495  0.116381 -0.012258 -0.122038 -0.050689 -0.264509  1.000000
# V8   0.489912 -0.057304 -0.150403 -0.088700  0.036185 -0.072025  0.181287
# V9   0.318498 -0.067867 -0.061683 -0.050094 -0.233063  0.204513 -0.112315
# V10  0.531266  0.135425 -0.218303 -0.043989  0.032803  0.074114  0.078157
# V11  0.523736  0.035146  0.051199 -0.196777 -0.012145  0.012075 -0.119209
#
#            V8        V9       V10       V11
# V1   0.489912  0.318498  0.531266  0.523736
# V2  -0.057304 -0.067867  0.135425  0.035146
# V3  -0.150403 -0.061683 -0.218303  0.051199
# V4  -0.088700 -0.050094 -0.043989 -0.196777
# V5   0.036185 -0.233063  0.032803 -0.012145
# V6  -0.072025  0.204513  0.074114  0.012075
# V7   0.181287 -0.112315  0.078157 -0.119209
# V8   1.000000 -0.023787  0.043716  0.176061
# V9  -0.023787  1.000000 -0.100084  0.011072
# V10  0.043716 -0.100084  1.000000  0.042817
# V11  0.176061  0.011072  0.042817  1.000000

# %%
import numpy as np

corr = df_regression.corr()

f, ax = plt.subplots(figsize=(10, 10))
ax = sns.heatmap(corr, annot=True, square=True)
